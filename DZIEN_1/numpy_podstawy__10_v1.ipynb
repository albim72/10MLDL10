# %%
print("To jest pierwsza komórka notebooka")
a = 145654
# Out:
# To jest pierwsza komórka notebooka

# %%
print(a*3)
# Out:
# 436962

# %% [markdown]
# To jest pierwszy **notebook** oparty na <span style="color:red; font-size:15pt;">Jupyter Notebook</span><br>
# Pokażemy bibliotekę numpy -> latex: $(x+1)^y$

# %%
import numpy as np

# %%
print(np.__version__)
# Out:
# 1.24.3

# %%
lista = [54,565,248,8,38,9,39,509,-576,3,0]
ar=np.array(lista)

# %%
print(lista)
print(ar)
# Out:
# [54, 565, 248, 8, 38, 9, 39, 509, -576, 3, 0]
# [  54  565  248    8   38    9   39  509 -576    3    0]

# %%
print(type(lista))
print(type(ar))
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>
